# %% [markdown]
# <a href="https://colab.research.google.com/github/ROHINI177/sb1-7fpgmb/blob/main/Datascience_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
pip install numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load the dataset
df_titanic = pd.read_csv(r'/content/gender_submission.csv')

# %%
df_titanic .head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#element of end
df_titanic .tail()
# Out:
#      PassengerId  Survived
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0

# %%
#get statistical summary
df_titanic.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['PassengerId'].plot(kind='hist', bins=20, title='PassengerId')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Survived'].plot(kind='hist', bins=20, title='Survived')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
#find null values
df_titanic .isnull()
# Out:
#      PassengerId  Survived
# 0          False     False
# 1          False     False
# 2          False     False
# 3          False     False
# 4          False     False
# ..           ...       ...
# 413        False     False
# 414        False     False
# 415        False     False
# 416        False     False
# 417        False     False
#
# [418 rows x 2 columns]

# %%
#number of null values
df_titanic .isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
df_titanic
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
#data types of data frame
df_titanic.dtypes
# Out:
# PassengerId    int64
# Survived       int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_automobile = pd.read_csv(r'/content/Automobile_data.csv')

# %%
df_automobile
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_automobile
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_automobile.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df_automobile.replace('?', np.NaN, inplace=True)

# %%
df_automobile
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_automobile.dropna(inplace=True)

# %%
df_automobile.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df_automobile
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2               164   audi       gas        std         four
# 4            2               164   audi       gas        std         four
# 6            1               158   audi       gas        std         four
# 8            1               158   audi       gas      turbo         four
# 10           2               192    bmw       gas        std          two
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
df_automobile = pd.get_dummies(df_automobile, columns=['fuel-type'])

# %%
df_automobile
# Out:
#      symboling normalized-losses   make aspiration num-of-doors body-style  \
# 3            2               164   audi        std         four      sedan
# 4            2               164   audi        std         four      sedan
# 6            1               158   audi        std         four      sedan
# 8            1               158   audi      turbo         four      sedan
# 10           2               192    bmw        std          two      sedan
# ..         ...               ...    ...        ...          ...        ...
# 200         -1                95  volvo        std         four      sedan
# 201         -1                95  volvo      turbo         four      sedan
# 202         -1                95  volvo        std         four      sedan
# 203         -1                95  volvo      turbo         four      sedan
# 204         -1                95  volvo      turbo         four      sedan
#
# ...

# %%
label = LabelEncoder()

# %%
  df_automobile['num-of-doors'] = label.fit_transform(df_automobile['num-of-doors'])

# %%
df_automobile
# Out:
#      symboling normalized-losses   make aspiration  num-of-doors body-style  \
# 3            2               164   audi        std             0      sedan
# 4            2               164   audi        std             0      sedan
# 6            1               158   audi        std             0      sedan
# 8            1               158   audi      turbo             0      sedan
# 10           2               192    bmw        std             1      sedan
# ..         ...               ...    ...        ...           ...        ...
# 200         -1                95  volvo        std             0      sedan
# 201         -1                95  volvo      turbo             0      sedan
# 202         -1                95  volvo        std             0      sedan
# 203         -1                95  volvo      turbo             0      sedan
# 204         -1                95  volvo      turbo             0      sedan
#
# ...
